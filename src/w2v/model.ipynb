# %%
import torch

# %%
model = torch.load('src/w2v/checkpoints/version-1/best_model_epoch_2_acc_2.5874.pt')

# %%
model
# Out:
# OrderedDict([('in_embed.weight',
#               tensor([[-0.0328,  0.1077,  0.0217,  ..., -0.0208, -0.0265,  0.1798],
#                       [-0.0194,  0.1923,  0.0472,  ..., -0.0345,  0.0235,  0.0638],
#                       [ 0.0135, -0.0674, -0.0605,  ...,  0.0391, -0.0349,  0.1251],
#                       ...,
#                       [ 0.1097,  0.0781, -0.4664,  ..., -0.6201,  0.8129,  0.3397],
#                       [ 0.6056,  0.3630,  0.8704,  ..., -0.0210, -0.1797,  0.3395],
#                       [ 0.5640,  0.8172,  0.3095,  ...,  0.7250,  0.3770, -0.3114]],
#                      device='cuda:0')),
#              ('out_embed.weight',
#               tensor([[-0.4750,  0.0559, -0.1208,  ...,  0.0524, -0.2907, -0.5738],
#                       [-0.4248,  0.0419, -0.0730,  ..., -0.0615, -0.4029, -0.5156],
#                       [-0.4774,  0.0055, -0.1136,  ...,  0.0694, -0.3341, -0.5497],
#                       ...,
#                       [-1.8397,  0.4639,  0.4636,  ...,  1.0430, -0.3642, -0.8234],
#                       [-0.5596, -0.0617,  0.1821,  ...,  0.4915, -1.4528, -1.1451],
#                       [-0.6900,  0.5975, -0.1851,  ...,  0.3489, -1.3249, -0.5067]],
#                      device='cuda:0'))])

# %%
embeddings = model['in_embed.weight'].to('cpu').data.numpy()

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

viz_words = 380
tsne = TSNE()
embed_tsne = tsne.fit_transform(embeddings[:viz_words, :])
fig, ax = plt.subplots(figsize=(16, 16))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    # plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
